# %% [markdown]
# Import pandas using the standard naming convention

# %%
import pandas as pd
import os

# %% [markdown]
# Grab the iris dataset in CSV format

# %%
os.system("curl https://raw.githubusercontent.com/pydata/pandas/master/pandas/tests/data/iris.csv > ~/iris.csv")
# Out:
# 1

# %% [markdown]
# Load the data into a data frame

# %%
df = pd.read_csv('~/iris.csv')

# %% [markdown]
# Set up matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib

# %%
matplotlib.style.use('ggplot')

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['x'] = df['petal_length'] * df['petal_width']

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species      x
# 0             5.1          3.5           1.4          0.2     setosa   0.28
# 1             4.9          3.0           1.4          0.2     setosa   0.28
# 2             4.7          3.2           1.3          0.2     setosa   0.26
# 3             4.6          3.1           1.5          0.2     setosa   0.30
# 4             5.0          3.6           1.4          0.2     setosa   0.28
# 5             5.4          3.9           1.7          0.4     setosa   0.68
# 6             4.6          3.4           1.4          0.3     setosa   0.42
# 7             5.0          3.4           1.5          0.2     setosa   0.30
# 8             4.4          2.9           1.4          0.2     setosa   0.28
# 9             4.9          3.1           1.5          0.1     setosa   0.15
# 10            5.4          3.7           1.5          0.2     setosa   0.30
# ...

# %% [markdown]
# Note index field that was automatically added

# %% [markdown]
# Explore th data frame

# %%
df.loc[3]
# Out:
# sepal_length       4.6
# sepal_width        3.1
# petal_length       1.5
# petal_width        0.2
# species         setosa
# Name: 3, dtype: object

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.0          3.3           1.4          0.2      setosa
# 1           6.7          3.0           5.0          1.7  versicolor
# 2           6.1          2.8           4.7          1.2  versicolor
# 3           6.0          3.0           4.8          1.8   virginica
# 4           4.8          3.4           1.6          0.2      setosa
# 5           6.4          2.7           5.3          1.9   virginica
# 6           5.4          3.4           1.7          0.2      setosa
# 7           4.4          3.0           1.3          0.2      setosa
# 8           6.8          2.8           4.8          1.4  versicolor
# 9           6.5          2.8           4.6          1.5  versicolor

# %%
round(df.sepal_length)
# Out:
# 0      5.0
# 1      7.0
# 2      6.0
# 3      6.0
# 4      5.0
# 5      6.0
# 6      5.0
# 7      4.0
# 8      7.0
# 9      6.0
# 10     7.0
# 11     6.0
# 12     6.0
# 13     5.0
# 14     6.0
# 15     6.0
# 16     5.0
# 17     5.0
# 18     6.0
# 19     6.0
# 20     6.0
# 21     6.0
# 22     5.0
# 23     6.0
# 24     5.0
# 25     8.0
# 26     6.0
# 27     7.0
# 28     6.0
# 29     6.0
#       ...
# 120    5.0
# 121    6.0
# 122    6.0
# 123    4.0
# 124    7.0
# 125    4.0
# 126    5.0
# 127    6.0
# 128    6.0
# 129    5.0
# 130    6.0
# 131    6.0
# 132    6.0
# 133    5.0
# 134    4.0
# 135    6.0
# 136    5.0
# 137    5.0
# 138    7.0
# 139    5.0
# 140    6.0
# 141    6.0
# 142    5.0
# 143    6.0
# 144    6.0
# 145    6.0
# 146    6.0
# 147    8.0
# 148    6.0
# 149    5.0
# Name: sepal_length, Length: 150, dtype: float64

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.tail(3)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Iris-setosa'],
# ...

# %%
df.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# Sorting

# %%
df.sort_index(ascending=False)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 149          5.9         3.0          5.1         1.8  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 144          6.7         3.3          5.7         2.5  Iris-virginica
# 143          6.8         3.2          5.9         2.3  Iris-virginica
# 142          5.8         2.7          5.1         1.9  Iris-virginica
# 141          6.9         3.1          5.1         2.3  Iris-virginica
# 140          6.7         3.1          5.6         2.4  Iris-virginica
# 139          6.9         3.1          5.4         2.1  Iris-virginica
# 138          6.0         3.0          4.8         1.8  Iris-virginica
# ...

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 6            4.6         3.4          1.4         0.3     Iris-setosa
# 7            5.0         3.4          1.5         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 9            4.9         3.1          1.5         0.1     Iris-setosa
# 10           5.4         3.7          1.5         0.2     Iris-setosa
# 11           4.8         3.4          1.6         0.2     Iris-setosa
# ...

# %%
df.sort_index(ascending=False, inplace=True)

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 149          5.9         3.0          5.1         1.8  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 144          6.7         3.3          5.7         2.5  Iris-virginica
# 143          6.8         3.2          5.9         2.3  Iris-virginica
# 142          5.8         2.7          5.1         1.9  Iris-virginica
# 141          6.9         3.1          5.1         2.3  Iris-virginica
# 140          6.7         3.1          5.6         2.4  Iris-virginica
# 139          6.9         3.1          5.4         2.1  Iris-virginica
# 138          6.0         3.0          4.8         1.8  Iris-virginica
# ...

# %%
df.sort_values(by = 'SepalWidth')
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 60           5.0         2.0          3.5         1.0  Iris-versicolor
# 119          6.0         2.2          5.0         1.5   Iris-virginica
# 68           6.2         2.2          4.5         1.5  Iris-versicolor
# 62           6.0         2.2          4.0         1.0  Iris-versicolor
# 87           6.3         2.3          4.4         1.3  Iris-versicolor
# 41           4.5         2.3          1.3         0.3      Iris-setosa
# 53           5.5         2.3          4.0         1.3  Iris-versicolor
# 93           5.0         2.3          3.3         1.0  Iris-versicolor
# 81           5.5         2.4          3.7         1.0  Iris-versicolor
# 80           5.5         2.4          3.8         1.1  Iris-versicolor
# 57           4.9         2.4          3.3         1.0  Iris-versicolor
# 113          5.7         2.5          5.0         2.0   Iris-virginica
# ...

# %% [markdown]
# Selection (this can get complicated). We'll start with the loc() method that pays attention to indexes.

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 6            4.6         3.4          1.4         0.3     Iris-setosa
# 7            5.0         3.4          1.5         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 9            4.9         3.1          1.5         0.1     Iris-setosa
# 10           5.4         3.7          1.5         0.2     Iris-setosa
# 11           4.8         3.4          1.6         0.2     Iris-setosa
# ...

# %%
df[10:20]
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 10          5.4         3.7          1.5         0.2  Iris-setosa
# 11          4.8         3.4          1.6         0.2  Iris-setosa
# 12          4.8         3.0          1.4         0.1  Iris-setosa
# 13          4.3         3.0          1.1         0.1  Iris-setosa
# 14          5.8         4.0          1.2         0.2  Iris-setosa
# 15          5.7         4.4          1.5         0.4  Iris-setosa
# 16          5.4         3.9          1.3         0.4  Iris-setosa
# 17          5.1         3.5          1.4         0.3  Iris-setosa
# 18          5.7         3.8          1.7         0.3  Iris-setosa
# 19          5.1         3.8          1.5         0.3  Iris-setosa

# %%
df.loc[12]
# Out:
# SepalLength            4.8
# SepalWidth               3
# PetalLength            1.4
# PetalWidth             0.1
# Name           Iris-setosa
# Name: 12, dtype: object

# %%
df.loc[40:50, ['SepalWidth', 'SepalLength']]
# Out:
#     SepalWidth  SepalLength
# 40         3.5          5.0
# 41         2.3          4.5
# 42         3.2          4.4
# 43         3.5          5.0
# 44         3.8          5.1
# 45         3.0          4.8
# 46         3.8          5.1
# 47         3.2          4.6
# 48         3.7          5.3
# 49         3.3          5.0
# 50         3.2          7.0

# %%
df.loc[10,'SepalWidth']
# Out:
# 3.7000000000000002

# %% [markdown]
# Now we'll move to the iloc() method, which pays attention to locations.  Let's resort the data frame so that the location (position in the data frame) and index do not line up perfectly.  That will help us see what's going on.

# %%
df.sort_index(ascending=False, inplace=True)

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 149          5.9         3.0          5.1         1.8  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 144          6.7         3.3          5.7         2.5  Iris-virginica
# 143          6.8         3.2          5.9         2.3  Iris-virginica
# 142          5.8         2.7          5.1         1.9  Iris-virginica
# 141          6.9         3.1          5.1         2.3  Iris-virginica
# 140          6.7         3.1          5.6         2.4  Iris-virginica
# 139          6.9         3.1          5.4         2.1  Iris-virginica
# 138          6.0         3.0          4.8         1.8  Iris-virginica
# ...

# %%
df.head(5)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 149          5.9         3.0          5.1         1.8  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 145          6.7         3.0          5.2         2.3  Iris-virginica

# %%
df.iloc[3]
# Out:
# SepalLength               6.3
# SepalWidth                2.5
# PetalLength                 5
# PetalWidth                1.9
# Name           Iris-virginica
# Name: 146, dtype: object

# %%
df.iloc[1:3, 2:5]
# Out:
#      PetalLength  PetalWidth            Name
# 148          5.4         2.3  Iris-virginica
# 147          5.2         2.0  Iris-virginica

# %%
df.iloc[1:3,:]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica

# %%
df.iloc[:,2:5]
# Out:
#      PetalLength  PetalWidth            Name
# 149          5.1         1.8  Iris-virginica
# 148          5.4         2.3  Iris-virginica
# 147          5.2         2.0  Iris-virginica
# 146          5.0         1.9  Iris-virginica
# 145          5.2         2.3  Iris-virginica
# 144          5.7         2.5  Iris-virginica
# 143          5.9         2.3  Iris-virginica
# 142          5.1         1.9  Iris-virginica
# 141          5.1         2.3  Iris-virginica
# 140          5.6         2.4  Iris-virginica
# 139          5.4         2.1  Iris-virginica
# 138          4.8         1.8  Iris-virginica
# 137          5.5         1.8  Iris-virginica
# 136          5.6         2.4  Iris-virginica
# 135          6.1         2.3  Iris-virginica
# 134          5.6         1.4  Iris-virginica
# 133          5.1         1.5  Iris-virginica
# 132          5.6         2.2  Iris-virginica
# 131          6.4         2.0  Iris-virginica
# 130          6.1         1.9  Iris-virginica
# ...

# %%
df.iloc[149,4]
# Out:
# 'Iris-setosa'

# %% [markdown]
# Boolean indexing!  This (I think) is very cool.

# %%
df[df.PetalWidth == 1.8]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 149          5.9         3.0          5.1         1.8   Iris-virginica
# 138          6.0         3.0          4.8         1.8   Iris-virginica
# 137          6.4         3.1          5.5         1.8   Iris-virginica
# 127          6.1         3.0          4.9         1.8   Iris-virginica
# 126          6.2         2.8          4.8         1.8   Iris-virginica
# 125          7.2         3.2          6.0         1.8   Iris-virginica
# 123          6.3         2.7          4.9         1.8   Iris-virginica
# 116          6.5         3.0          5.5         1.8   Iris-virginica
# 108          6.7         2.5          5.8         1.8   Iris-virginica
# 107          7.3         2.9          6.3         1.8   Iris-virginica
# 103          6.3         2.9          5.6         1.8   Iris-virginica
# 70           5.9         3.2          4.8         1.8  Iris-versicolor

# %%
df[df['Name'].isin(['Iris-virginica', 'Iris-versicolor'])]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 149          5.9         3.0          5.1         1.8   Iris-virginica
# 148          6.2         3.4          5.4         2.3   Iris-virginica
# 147          6.5         3.0          5.2         2.0   Iris-virginica
# 146          6.3         2.5          5.0         1.9   Iris-virginica
# 145          6.7         3.0          5.2         2.3   Iris-virginica
# 144          6.7         3.3          5.7         2.5   Iris-virginica
# 143          6.8         3.2          5.9         2.3   Iris-virginica
# 142          5.8         2.7          5.1         1.9   Iris-virginica
# 141          6.9         3.1          5.1         2.3   Iris-virginica
# 140          6.7         3.1          5.6         2.4   Iris-virginica
# 139          6.9         3.1          5.4         2.1   Iris-virginica
# 138          6.0         3.0          4.8         1.8   Iris-virginica
# ...

# %% [markdown]
# Setting values using the index

# %%
df.loc[10]
# Out:
# SepalLength            5.4
# SepalWidth             3.7
# PetalLength            1.5
# PetalWidth             0.2
# Name           Iris-setosa
# Name: 10, dtype: object

# %%
df.at[10,'SepalLength'] = 123.456

# %%
df.loc[10]
# Out:
# SepalLength        123.456
# SepalWidth             3.7
# PetalLength            1.5
# PetalWidth             0.2
# Name           Iris-setosa
# Name: 10, dtype: object

# %%
df.iloc[139]
# Out:
# SepalLength        123.456
# SepalWidth             3.7
# PetalLength            1.5
# PetalWidth             0.2
# Name           Iris-setosa
# Name: 10, dtype: object

# %% [markdown]
# Why did I do iloc above?

# %%
df.iat[139, 0] = 654.321

# %%
df.iloc[139]
# Out:
# SepalLength        654.321
# SepalWidth             3.7
# PetalLength            1.5
# PetalWidth             0.2
# Name           Iris-setosa
# Name: 10, dtype: object
